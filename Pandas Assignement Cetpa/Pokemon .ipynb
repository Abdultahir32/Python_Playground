# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.shape
# Out:
# (800, 12)

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      359 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.describe(include='object')
# Out:
#              Name Type 1  Type 2
# count         800    800     359
# unique        800     18      18
# top     Bulbasaur  Water  Flying
# freq            1    112      81

# %%
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        441
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# #              0.000
# Name           0.000
# Type 1         0.000
# Type 2        55.125
# HP             0.000
# Attack         0.000
# Defense        0.000
# Sp. Atk        0.000
# Sp. Def        0.000
# Speed          0.000
# Generation     0.000
# Legendary      0.000
# dtype: float64

# %%
df.drop(columns=['Type 2'],inplace=True)

# %%
df.drop(columns=['#'],inplace=True)

# %%
df
# Out:
#                       Name   Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0                Bulbasaur    Grass  45      49       49       65       65
# 1                  Ivysaur    Grass  60      62       63       80       80
# 2                 Venusaur    Grass  80      82       83      100      100
# 3    VenusaurMega Venusaur    Grass  80     100      123      122      120
# 4               Charmander     Fire  39      52       43       60       50
# ..                     ...      ...  ..     ...      ...      ...      ...
# 795                Diancie     Rock  50     100      150      100      150
# 796    DiancieMega Diancie     Rock  50     160      110      160      110
# 797    HoopaHoopa Confined  Psychic  80     110       60      150      130
# 798     HoopaHoopa Unbound  Psychic  80     160       60      170      130
# 799              Volcanion     Fire  80     110      120      130       90
#
#      Speed  Generation  Legendary
# ...

# %%
df['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
for i in df['Name']:
    print(i)
# Out:
# Bulbasaur
# Ivysaur
# Venusaur
# VenusaurMega Venusaur
# Charmander
# Charmeleon
# Charizard
# CharizardMega Charizard X
# CharizardMega Charizard Y
# Squirtle
# Wartortle
# Blastoise
# BlastoiseMega Blastoise
# Caterpie
# Metapod
# Butterfree
# Weedle
# Kakuna
# Beedrill
# BeedrillMega Beedrill
# Pidgey
# Pidgeotto
# Pidgeot
# PidgeotMega Pidgeot
# Rattata
# Raticate
# Spearow
# Fearow
# Ekans
# Arbok
# Pikachu
# Raichu
# Sandshrew
# Sandslash
# Nidoran (Female)
# Nidorina
# Nidoqueen
# Nidoran (Male)
# Nidorino
# Nidoking
# Clefairy
# Clefable
# Vulpix
# Ninetales
# Jigglypuff
# Wigglytuff
# Zubat
# Golbat
# Oddish
# Gloom
# Vileplume
# Paras
# Parasect
# Venonat
# Venomoth
# Diglett
# Dugtrio
# Meowth
# Persian
# Psyduck
# Golduck
# Mankey
# Primeape
# Growlithe
# Arcanine
# Poliwag
# Poliwhirl
# Poliwrath
# Abra
# Kadabra
# Alakazam
# AlakazamMega Alakazam
# Machop
# Machoke
# Machamp
# Bellsprout
# Weepinbell
# Victreebel
# Tentacool
# Tentacruel
# Geodude
# Graveler
# Golem
# ...

# %%
df[['Name','Type 1','HP']]
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
df[['Name','Type 1','HP']][200:221]
# Out:
#            Name   Type 1   HP
# 200   Sudowoodo     Rock   70
# 201    Politoed    Water   90
# 202      Hoppip    Grass   35
# 203    Skiploom    Grass   55
# 204    Jumpluff    Grass   75
# 205       Aipom   Normal   55
# 206     Sunkern    Grass   30
# 207    Sunflora    Grass   75
# 208       Yanma      Bug   65
# 209      Wooper    Water   55
# 210    Quagsire    Water   95
# 211      Espeon  Psychic   65
# 212     Umbreon     Dark   95
# 213     Murkrow     Dark   60
# 214    Slowking    Water   95
# 215  Misdreavus    Ghost   60
# 216       Unown  Psychic   48
# 217   Wobbuffet  Psychic  190
# 218   Girafarig   Normal   70
# 219      Pineco      Bug   50
# 220  Forretress      Bug   75

# %%
df.iloc[200:221,0:4]
# Out:
#            Name   Type 1   HP  Attack
# 200   Sudowoodo     Rock   70     100
# 201    Politoed    Water   90      75
# 202      Hoppip    Grass   35      35
# 203    Skiploom    Grass   55      45
# 204    Jumpluff    Grass   75      55
# 205       Aipom   Normal   55      70
# 206     Sunkern    Grass   30      30
# 207    Sunflora    Grass   75      75
# 208       Yanma      Bug   65      65
# 209      Wooper    Water   55      45
# 210    Quagsire    Water   95      85
# 211      Espeon  Psychic   65      65
# 212     Umbreon     Dark   95      65
# 213     Murkrow     Dark   60      85
# 214    Slowking    Water   95      75
# 215  Misdreavus    Ghost   60      60
# 216       Unown  Psychic   48      72
# 217   Wobbuffet  Psychic  190      33
# 218   Girafarig   Normal   70      80
# 219      Pineco      Bug   50      65
# 220  Forretress      Bug   75      90

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df['Type 1'].nunique()
# Out:
# 18

# %%
df['Type 1'].value_counts()   # frequency check krte hai
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
df['Type 1'].mode()
# Out:
# 0    Water
# Name: Type 1, dtype: object

# %%
df.sort_values(by='Attack')
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 488                  Happiny   Normal  100       5        5       15       65
# 121                  Chansey   Normal  250       5        5       35      105
# 230                  Shuckle      Bug   20      10      230       10      230
# 261                  Blissey   Normal  255      10       10       75      135
# 139                 Magikarp    Water   20      10       55       15       20
# ..                       ...      ...  ...     ...      ...      ...      ...
# 429       DeoxysAttack Forme  Psychic   50     180       20      180       20
# 426    RayquazaMega Rayquaza   Dragon  105     180      100      180      100
# 424    GroudonPrimal Groudon   Ground  100     180      160      150       90
# 232  HeracrossMega Heracross      Bug   80     185      115       40      105
# 163      MewtwoMega Mewtwo X  Psychic  106     190      100      154      100
#
# ...

# %%
df.sort_values(by='Attack', ascending=False)
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 163      MewtwoMega Mewtwo X  Psychic  106     190      100      154      100
# 232  HeracrossMega Heracross      Bug   80     185      115       40      105
# 424    GroudonPrimal Groudon   Ground  100     180      160      150       90
# 426    RayquazaMega Rayquaza   Dragon  105     180      100      180      100
# 429       DeoxysAttack Forme  Psychic   50     180       20      180       20
# ..                       ...      ...  ...     ...      ...      ...      ...
# 139                 Magikarp    Water   20      10       55       15       20
# 261                  Blissey   Normal  255      10       10       75      135
# 230                  Shuckle      Bug   20      10      230       10      230
# 121                  Chansey   Normal  250       5        5       35      105
# 488                  Happiny   Normal  100       5        5       15       65
#
# ...

# %%
df.sort_values(by='Name', ascending=False)
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 794         Zygarde50% Forme   Dragon  108     100      121       81       95
# 695                 Zweilous     Dark   72      85       70       65       70
# 46                     Zubat   Poison   40      45       35       30       40
# 631                    Zorua     Dark   40      65       40       80       40
# 632                  Zoroark     Dark   60     105       60      120       60
# ..                       ...      ...  ...     ...      ...      ...      ...
# 393          AbsolMega Absol     Dark   65     150       60      115       60
# 392                    Absol     Dark   65     130       60       75       60
# 68                      Abra  Psychic   25      20       15      105       55
# 511  AbomasnowMega Abomasnow    Grass   90     132      105      132      105
# 510                Abomasnow    Grass   90      92       75       92       85
#
# ...

# %%
df.sort_values(by=['Attack','Speed'],ascending=[False,False])
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 163      MewtwoMega Mewtwo X  Psychic  106     190      100      154      100
# 232  HeracrossMega Heracross      Bug   80     185      115       40      105
# 429       DeoxysAttack Forme  Psychic   50     180       20      180       20
# 426    RayquazaMega Rayquaza   Dragon  105     180      100      180      100
# 424    GroudonPrimal Groudon   Ground  100     180      160      150       90
# ..                       ...      ...  ...     ...      ...      ...      ...
# 139                 Magikarp    Water   20      10       55       15       20
# 261                  Blissey   Normal  255      10       10       75      135
# 230                  Shuckle      Bug   20      10      230       10      230
# 121                  Chansey   Normal  250       5        5       35      105
# 488                  Happiny   Normal  100       5        5       15       65
#
# ...

# %%
df.head()
# Out:
#                     Name Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0              Bulbasaur  Grass  45      49       49       65       65     45
# 1                Ivysaur  Grass  60      62       63       80       80     60
# 2               Venusaur  Grass  80      82       83      100      100     80
# 3  VenusaurMega Venusaur  Grass  80     100      123      122      120     80
# 4             Charmander   Fire  39      52       43       60       50     65
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False

# %%
df['Total'] = df.iloc[:,2:8].sum(axis=1)

# %%
df
# Out:
#                       Name   Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0                Bulbasaur    Grass  45      49       49       65       65
# 1                  Ivysaur    Grass  60      62       63       80       80
# 2                 Venusaur    Grass  80      82       83      100      100
# 3    VenusaurMega Venusaur    Grass  80     100      123      122      120
# 4               Charmander     Fire  39      52       43       60       50
# ..                     ...      ...  ..     ...      ...      ...      ...
# 795                Diancie     Rock  50     100      150      100      150
# 796    DiancieMega Diancie     Rock  50     160      110      160      110
# 797    HoopaHoopa Confined  Psychic  80     110       60      150      130
# 798     HoopaHoopa Unbound  Psychic  80     160       60      170      130
# 799              Volcanion     Fire  80     110      120      130       90
#
#      Speed  Generation  Legendary  Total
# ...

# %% [markdown]
# # Filtering

# %%
df[df['Type 1'] == 'Flying']
# Out:
#                         Name  Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 702  TornadusIncarnate Forme  Flying  79     115       70      125       80
# 703    TornadusTherian Forme  Flying  79     100       80      110       90
# 790                   Noibat  Flying  40      30       35       45       40
# 791                  Noivern  Flying  85      70       80       97       80
#
#      Speed  Generation  Legendary  Total
# 702    111           5       True    580
# 703    121           5       True    580
# 790     55           6      False    245
# 791    123           6      False    535

# %%
df[df['Type 1'] == 'Fairy']
# Out:
#            Name Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 40     Clefairy  Fairy   70      45       48       60       65     35
# 41     Clefable  Fairy   95      70       73       95       90     60
# 187      Cleffa  Fairy   50      25       28       45       55     15
# 189      Togepi  Fairy   35      20       65       40       65     20
# 190     Togetic  Fairy   55      40       85       80      105     40
# 225    Snubbull  Fairy   60      80       50       40       40     30
# 226    Granbull  Fairy   90     120       75       60       60     45
# 519    Togekiss  Fairy   85      50       95      120      115     80
# 737     Flabébé  Fairy   44      38       39       61       79     42
# 738     Floette  Fairy   54      45       47       75       98     52
# 739     Florges  Fairy   78      65       68      112      154     75
# 752    Spritzee  Fairy   78      52       60       63       65     23
# ...

# %%
df[df['Attack']>150]
# Out:
#                         Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 137        PinsirMega Pinsir      Bug   65     155      120       65       90
# 141    GyaradosMega Gyarados    Water   95     155      109       70      130
# 163      MewtwoMega Mewtwo X  Psychic  106     190      100      154      100
# 232  HeracrossMega Heracross      Bug   80     185      115       40      105
# 268  TyranitarMega Tyranitar     Rock  100     164      150       95      120
# 279    BlazikenMega Blaziken     Fire   80     160       80      130       80
# 313                  Slaking   Normal  150     160      100       95       65
# 387      BanetteMega Banette    Ghost   64     165       75       93       83
# 424    GroudonPrimal Groudon   Ground  100     180      160      150       90
# 426    RayquazaMega Rayquaza   Dragon  105     180      100      180      100
# 429       DeoxysAttack Forme  Psychic   50     180       20      180       20
# ...

# %%
df[(df['Type 1'] == 'Fairy') & (df['Attack']<50)]
# Out:
#          Name Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 40   Clefairy  Fairy  70      45       48       60       65     35
# 187    Cleffa  Fairy  50      25       28       45       55     15
# 189    Togepi  Fairy  35      20       65       40       65     20
# 190   Togetic  Fairy  55      40       85       80      105     40
# 737   Flabébé  Fairy  44      38       39       61       79     42
# 738   Floette  Fairy  54      45       47       75       98     52
# 754   Swirlix  Fairy  62      48       66       59       57     49
#
#      Generation  Legendary  Total
# 40            1      False    323
# 187           2      False    218
# 189           2      False    245
# 190           2      False    405
# 737           6      False    303
# 738           6      False    371
# 754           6      False    341

# %%
df[(df['Type 1'] == 'Fairy') | (df['Type 1'] == 'Flying')]
# Out:
#                         Name  Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 40                  Clefairy   Fairy   70      45       48       60       65
# 41                  Clefable   Fairy   95      70       73       95       90
# 187                   Cleffa   Fairy   50      25       28       45       55
# 189                   Togepi   Fairy   35      20       65       40       65
# 190                  Togetic   Fairy   55      40       85       80      105
# 225                 Snubbull   Fairy   60      80       50       40       40
# 226                 Granbull   Fairy   90     120       75       60       60
# 519                 Togekiss   Fairy   85      50       95      120      115
# 702  TornadusIncarnate Forme  Flying   79     115       70      125       80
# 703    TornadusTherian Forme  Flying   79     100       80      110       90
# 737                  Flabébé   Fairy   44      38       39       61       79
# ...

# %%
df[(df['Legendary'] == 'Fairy') | (df['Legendary'] != 'Fairy')]
# Out:
#                       Name   Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0                Bulbasaur    Grass  45      49       49       65       65
# 1                  Ivysaur    Grass  60      62       63       80       80
# 2                 Venusaur    Grass  80      82       83      100      100
# 3    VenusaurMega Venusaur    Grass  80     100      123      122      120
# 4               Charmander     Fire  39      52       43       60       50
# ..                     ...      ...  ..     ...      ...      ...      ...
# 795                Diancie     Rock  50     100      150      100      150
# 796    DiancieMega Diancie     Rock  50     160      110      160      110
# 797    HoopaHoopa Confined  Psychic  80     110       60      150      130
# 798     HoopaHoopa Unbound  Psychic  80     160       60      170      130
# 799              Volcanion     Fire  80     110      120      130       90
#
#      Speed  Generation  Legendary  Total
# ...

# %% [markdown]
# # Aggregation

# %%
df
# Out:
#                       Name   Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0                Bulbasaur    Grass  45      49       49       65       65
# 1                  Ivysaur    Grass  60      62       63       80       80
# 2                 Venusaur    Grass  80      82       83      100      100
# 3    VenusaurMega Venusaur    Grass  80     100      123      122      120
# 4               Charmander     Fire  39      52       43       60       50
# ..                     ...      ...  ..     ...      ...      ...      ...
# 795                Diancie     Rock  50     100      150      100      150
# 796    DiancieMega Diancie     Rock  50     160      110      160      110
# 797    HoopaHoopa Confined  Psychic  80     110       60      150      130
# 798     HoopaHoopa Unbound  Psychic  80     160       60      170      130
# 799              Volcanion     Fire  80     110      120      130       90
#
#      Speed  Generation  Legendary  Total
# ...

# %%
df.groupby(['Type 1'])['Attack'].sum().sort_values(ascending=False).reset_index()
# Out:
#       Type 1  Attack
# 0      Water    8305
# 1     Normal    7200
# 2      Grass    5125
# 3        Bug    4897
# 4       Fire    4408
# 5       Rock    4086
# 6    Psychic    4073
# 7     Dragon    3588
# 8     Ground    3064
# 9   Electric    3040
# 10      Dark    2740
# 11  Fighting    2613
# 12     Steel    2503
# 13     Ghost    2361
# 14    Poison    2091
# 15       Ice    1746
# 16     Fairy    1046
# 17    Flying     315

# %%
df.groupby(['Type 1'])['Attack'].agg(['mean','max','sum','min']).sort_values(by='mean',ascending=False)
# Out:
#                 mean  max   sum  min
# Type 1
# Dragon    112.125000  180  3588   50
# Fighting   96.777778  145  2613   35
# Ground     95.750000  180  3064   40
# Rock       92.863636  165  4086   40
# Steel      92.703704  150  2503   24
# Dark       88.387097  150  2740   50
# Fire       84.769231  160  4408   30
# Flying     78.750000  115   315   30
# Poison     74.678571  106  2091   43
# Water      74.151786  155  8305   10
# Ghost      73.781250  165  2361   30
# Normal     73.469388  160  7200    5
# Grass      73.214286  132  5125   27
# Ice        72.750000  130  1746   30
# Psychic    71.456140  190  4073   20
# Bug        70.971014  185  4897   10
# Electric   69.090909  123  3040   30
# Fairy      61.529412  131  1046   20

# %%
df
# Out:
#                       Name   Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0                Bulbasaur    Grass  45      49       49       65       65
# 1                  Ivysaur    Grass  60      62       63       80       80
# 2                 Venusaur    Grass  80      82       83      100      100
# 3    VenusaurMega Venusaur    Grass  80     100      123      122      120
# 4               Charmander     Fire  39      52       43       60       50
# ..                     ...      ...  ..     ...      ...      ...      ...
# 795                Diancie     Rock  50     100      150      100      150
# 796    DiancieMega Diancie     Rock  50     160      110      160      110
# 797    HoopaHoopa Confined  Psychic  80     110       60      150      130
# 798     HoopaHoopa Unbound  Psychic  80     160       60      170      130
# 799              Volcanion     Fire  80     110      120      130       90
#
#      Speed  Generation  Legendary  Total
# ...

# %%
df.to_csv('update_pok.csv', index=False)
