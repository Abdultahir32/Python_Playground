# %%
import numpy as np
import pandas as pd

# %%
d=pd.date_range('1-1-2021',periods=367)

# %%
d
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08',
#                '2021-01-09', '2021-01-10',
#                ...
#                '2021-12-24', '2021-12-25', '2021-12-26', '2021-12-27',
#                '2021-12-28', '2021-12-29', '2021-12-30', '2021-12-31',
#                '2022-01-01', '2022-01-02'],
#               dtype='datetime64[ns]', length=367, freq='D')

# %%
df = pd.DataFrame(d, columns=['date'])

# %%
df
# Out:
#           date
# 0   2021-01-01
# 1   2021-01-02
# 2   2021-01-03
# 3   2021-01-04
# 4   2021-01-05
# ..         ...
# 362 2021-12-29
# 363 2021-12-30
# 364 2021-12-31
# 365 2022-01-01
# 366 2022-01-02
#
# [367 rows x 1 columns]

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day

# %%
df['week'] = df['date'].dt.day_name()
df['months'] = df['date'].dt.month_name()

# %%
df
# Out:
#           date  year  month  day       week    months
# 0   2021-01-01  2021      1    1     Friday   January
# 1   2021-01-02  2021      1    2   Saturday   January
# 2   2021-01-03  2021      1    3     Sunday   January
# 3   2021-01-04  2021      1    4     Monday   January
# 4   2021-01-05  2021      1    5    Tuesday   January
# ..         ...   ...    ...  ...        ...       ...
# 362 2021-12-29  2021     12   29  Wednesday  December
# 363 2021-12-30  2021     12   30   Thursday  December
# 364 2021-12-31  2021     12   31     Friday  December
# 365 2022-01-01  2022      1    1   Saturday   January
# 366 2022-01-02  2022      1    2     Sunday   January
#
# [367 rows x 6 columns]

# %%
sales = np.random.randint(1000, 10000, df.shape[0])

# %%
df['sales'] = sales

# %%
df
# Out:
#           date  year  month  day       week    months  sales
# 0   2021-01-01  2021      1    1     Friday   January   5906
# 1   2021-01-02  2021      1    2   Saturday   January   5852
# 2   2021-01-03  2021      1    3     Sunday   January   3108
# 3   2021-01-04  2021      1    4     Monday   January   3049
# 4   2021-01-05  2021      1    5    Tuesday   January   5943
# ..         ...   ...    ...  ...        ...       ...    ...
# 362 2021-12-29  2021     12   29  Wednesday  December   8185
# 363 2021-12-30  2021     12   30   Thursday  December   5343
# 364 2021-12-31  2021     12   31     Friday  December   2668
# 365 2022-01-01  2022      1    1   Saturday   January   5543
# 366 2022-01-02  2022      1    2     Sunday   January   8964
#
# [367 rows x 7 columns]

# %% [markdown]
# # ##calculate the total revenue each month

# %%
df.groupby(['month'])['sales'].sum().sort_values(ascending=False)
# Out:
# month
# 3     186635
# 1     180745
# 12    177872
# 5     170282
# 10    163897
# 8     163177
# 9     156126
# 7     153180
# 11    150180
# 2     149655
# 4     149301
# 6     138350
# Name: sales, dtype: int32

# %% [markdown]
# # on which date has data has an maximum sales

# %%
df[df['sales'] == df['sales'].max()]
# Out:
#          date  year  month  day    week months  sales
# 59 2021-03-01  2021      3    1  Monday  March   9996

# %% [markdown]
# ## on what day tahe data has generated the total revenue is weekday and weekend

# %%
df['W'] = df['weeks'].apply(lambda i: 'weekend' if i == 'sunday' or i=='saturday' else 'weekdays')

# %%
df.groupby(['W'])['sales'].sum()
# Out:
# W
# weekdays    2105186
# Name: sales, dtype: int32

# %%
import numpy as np
import pandas as pd

# %%
p = pd.date_range('2020-1-1',periods=367)
p
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-12-23', '2020-12-24', '2020-12-25', '2020-12-26',
#                '2020-12-27', '2020-12-28', '2020-12-29', '2020-12-30',
#                '2020-12-31', '2021-01-01'],
#               dtype='datetime64[ns]', length=367, freq='D')

# %%
df = pd.DataFrame(p,columns=['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    367 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 3.0 KB

# %%
df
# Out:
#           date
# 0   2020-01-01
# 1   2020-01-02
# 2   2020-01-03
# 3   2020-01-04
# 4   2020-01-05
# ..         ...
# 362 2020-12-28
# 363 2020-12-29
# 364 2020-12-30
# 365 2020-12-31
# 366 2021-01-01
#
# [367 rows x 1 columns]

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['week'] = df['date'].dt.day

# %%
df['months'] = df['date'].dt.month_name()
df['weeks'] = df['date'].dt.day_name()

# %%
sales = np.random.randint(1000,10000 ,df.shape[0])

# %%
df['sales'] = sales

# %%
df
# Out:
#           date  year  month  week    months      weeks  sales
# 0   2020-01-01  2020      1     1   January  Wednesday   9222
# 1   2020-01-02  2020      1     2   January   Thursday   4954
# 2   2020-01-03  2020      1     3   January     Friday   2328
# 3   2020-01-04  2020      1     4   January   Saturday   7233
# 4   2020-01-05  2020      1     5   January     Sunday   2088
# ..         ...   ...    ...   ...       ...        ...    ...
# 362 2020-12-28  2020     12    28  December     Monday   8468
# 363 2020-12-29  2020     12    29  December    Tuesday   1607
# 364 2020-12-30  2020     12    30  December  Wednesday   5980
# 365 2020-12-31  2020     12    31  December   Thursday   2793
# 366 2021-01-01  2021      1     1   January     Friday   5978
#
# [367 rows x 7 columns]

# %%
 df.groupby(['month'])['sales'].sum().sort_values(ascending=False)
# Out:
# month
# 1     201365
# 8     201214
# 11    200077
# 7     199966
# 3     179259
# 12    177834
# 5     172545
# 6     168800
# 10    163888
# 2     163222
# 9     144003
# 4     133013
# Name: sales, dtype: int32

# %%
df[df['sales']==df['sales'].max()]
# Out:
#     date  year  month  week   months      weeks  sales
# 14   NaN  2020      1    15  January  Wednesday   9983

# %%
df['W'] = df['weeks'].apply(lambda i: 'weekend' if i == 'sunday' or i=='saturday' else 'weekdays')

# %%
df.groupby(['W'])['sales'].sum()
# Out:
# W
# weekdays    2105186
# Name: sales, dtype: int32

# %%
df['quat_name'] = df['date'].dt.quarter
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df['quat_name'] = df['date'].dt.quarter
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...

# %%
df

# %%
df['quarter'] = df['date'].dt.quarter
df['quarter_start_month'] = df['date'].dt.to_period('Q').dt.start_time.dt.month
df['quarter_end_month'] = df['date'].dt.to_period('Q').dt.end_time.dt.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df['quarter'] = df['date'].dt.quarter
#       2 df['quarter_start_month'] = df['date'].dt.to_period('Q').dt.start_time.dt.month
#       3 df['quarter_end_month'] = df['date'].dt.to_period('Q').dt.end_time.dt.month
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
# ...
